# %%
import numpy 
import sys
import pandas
import matplotlib
import seaborn
import scipy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dts=pd.read_csv(r'C:\Users\hp\Downloads\creditcard.csv')

# %%
dts.head(1000)
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 0      0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1      0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2      1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3      1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4      2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5      2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6      4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7      7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8      7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9      9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10    10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11    10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# ...

# %%
dts.columns,dts.shape
# Out:
# (Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#         'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#         'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#         'Class'],
#        dtype='object'), (284807, 31))

# %%
dts.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
dts.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
dts.shape
# Out:
# (284807, 31)

# %%
#detecting the fraud cases
fraud=dts[dts['Class']==1]
valid=dts[dts['Class']==0]

outlier_fraction=len(fraud)/float(len(valid))
outlier_fraction,len(fraud),len(valid)
# Out:
# (0.0017304750013189597, 492, 284315)

# %%
columns=dts.columns
columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
x=dts[['Time','Amount']]
#x=data.drop(['Class'],axis=1)
y=dts['Class']
x.shape,y.shape
# Out:
# ((284807, 2), (284807,))

# %%
dts.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
x_tr,x_ts,y_tr,y_ts=train_test_split(x,y,test_size=0.1)#classify data as training set and test set
print(x_tr.shape)
# Out:
# (256326, 2)

# %%
algo1=KNeighborsClassifier()
algo1.fit(x_tr,y_tr)
algo1.score(x_ts,y_ts)
# Out:
# 0.9982795547909132

# %%
from sklearn.linear_model import LogisticRegression
algo2=LogisticRegression()
algo2.fit(x_tr,y_tr)
algo2.score(x_ts,y_ts)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9982444436641972

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_ts,algo.predict(x_ts)))
# Out:
# [[28431     0]
#  [   50     0]]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_ts,algo.predict(x_ts)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     28431
#            1       0.00      0.00      0.00        50
#
#    micro avg       1.00      1.00      1.00     28481
#    macro avg       0.50      0.50      0.50     28481
# weighted avg       1.00      1.00      1.00     28481
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
x.head()
# Out:
#    Time  Amount
# 0   0.0  149.62
# 1   0.0    2.69
# 2   1.0  378.66
# 3   1.0  123.50
# 4   2.0   69.99

# %%
s=np.array([['1.0','378.66']])
y_pred=algo.predict(s.astype(np.float))
y_pred
# Out:
# array([0], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
algo3=DecisionTreeClassifier()

algo3.fit(x_tr,y_tr)
algo3.score(x_ts,y_ts)
# Out:
# 0.9971208876092834

# %%
from sklearn.ensemble import RandomForestClassifier
algo4=RandomForestClassifier()i
algo4.fit(x_tr,y_tr)
algo4.score(x_ts,y_ts)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.9979284435237527

# %%
algo1.score(x_ts,y_ts),algo2.score(x_ts,y_ts),algo3.score(x_ts,y_ts),algo4.score(x_ts,y_ts)
# Out:
# (0.9982795547909132,
#  0.9982444436641972,
#  0.9971208876092834,
#  0.9979284435237527)

# %%
acc=[]
acc=[algo1.score(x_ts,y_ts),algo2.score(x_ts,y_ts),algo3.score(x_ts,y_ts),algo4.score(x_ts,y_ts)]

# %%
acc=sorted(acc)

# %%
acc
# Out:
# [0.9971208876092834,
#  0.9979284435237527,
#  0.9982444436641972,
#  0.9982795547909132]
